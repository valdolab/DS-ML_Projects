# %% [markdown]
# # Time series processing

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

# %%
data_set = pd.read_csv("dataset_day1_1fp2s_mean5min.csv")
data_set['ds'] = pd.to_datetime("08:02")
data_set.head()
data_set['ds'] += pd.TimedeltaIndex(data_set.groupby('ds').cumcount()*5, unit='m')
data_set['ds'] = list(map(lambda x: x.time(), data_set['ds']))
data_set
# Out:
#      Unnamed: 0        ds        ts
# 0             0  08:02:00  0.233333
# 1             1  08:07:00  0.153333
# 2             2  08:12:00  0.093333
# 3             3  08:17:00  0.046667
# 4             4  08:22:00  0.200000
# ..          ...       ...       ...
# 106         106  16:52:00  0.046667
# 107         107  16:57:00  0.180000
# 108         108  17:02:00  0.173333
# 109         109  17:07:00  0.033333
# 110         110  17:12:00  0.053333
#
# [111 rows x 3 columns]

# %%
data_set.plot(x="ds", y="ts")
# Out:
# <AxesSubplot:xlabel='ds'>

# %% [markdown]
# ## Some pre-processing

# %%
smooted_ts = data_set['ts'].rolling(2).sum()

# %%
smooted_ts.plot(x="ds", y="ts")
# Out:
# <AxesSubplot:>
